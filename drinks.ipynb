# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv', delimiter=',')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       170 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
df.iloc[np.argsort(df.total_litres_of_pure_alcohol)[:10]]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 147        San Marino              0                0              0
# 128          Pakistan              0                0              0
# 46        North Korea              0                0              0
# 13         Bangladesh              0                0              0
# 111            Monaco              0                0              0
# 106  Marshall Islands              0                0              0
# 103          Maldives              0                0              0
# 107        Mauritania              0                0              0
# 90             Kuwait              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 147                           0.0        EU
# 128                           0.0        AS
# ...

# %%
df.iloc[np.argsort(df.total_litres_of_pure_alcohol)[:-10:-1]]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
#
#      total_litres_of_pure_alcohol continent
# 15                           14.4        EU
# 98                           12.9        EU
# 3                            12.4        EU
# 68                           11.9       NaN
# ...

# %%
df.total_litres_of_pure_alcohol.hist()

# %%
df.total_litres_of_pure_alcohol.plot(kind='box')
